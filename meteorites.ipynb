# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %%
asteroids = pd.read_csv("asteriods.csv")
asteroids_cleaned = asteroids.drop(labels=['n_del_obs_used', 'n_dop_obs_used', 'two_body', 'H'], axis='columns')
asteroids_cleaned
# Out:
#                        full_name       e      q       i      om       w  \
# 0                      1P/Halley  0.9679  0.575  162.19   59.11  112.26
# 1                       2P/Encke  0.8483  0.336   11.78  334.56  186.56
# 2                       3D/Biela  0.7513  0.879   13.22  250.67  221.66
# 3                        4P/Faye  0.5845  1.578    8.16  194.80  205.99
# 4                     5D/Brorsen  0.8098  0.590   29.38  102.97   14.95
# ...                          ...     ...    ...     ...     ...     ...
# 3883       P/2023 M2 (PANSTARRS)  0.3693  3.508   19.73   83.27  243.01
# 3884           P/2023 M4 (ATLAS)  0.2794  3.929    7.59  296.30  320.69
# 3885       C/2023 P1 (Nishimura)  0.9961  0.225  132.48   66.83  116.30
# 3886       C/2023 R1 (PANSTARRS)  0.9984  3.569  149.31   62.54  144.39
# 3887                   P/2023 S1  0.3178  2.628    9.16  317.84  179.55
#
#            ad        tp_cal      per_y class  data_arc  condition_code  \
# ...

# %%
comets = pd.read_csv("comets.csv")
comets_cleaned = comets.drop(labels=['A1', 'A2', 'A3', 'DT','n_del_obs_used', 'n_dop_obs_used', 'two_body'], axis='columns')
comets_cleaned.head()
# Out:
# /var/folders/89/p8m4_pw97bqd50p4gzhm5yqw0000gn/T/ipykernel_43606/1138420568.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   comets = pd.read_csv("comets.csv")
#                   full_name       e      q      i      om       w    ad  \
# 0       65 Cybele (A861 EB)  0.1222  3.007   3.56  155.37  103.36  3.84
# 1        76 Freia (A862 UA)  0.1670  2.842   2.12  204.29  251.99  3.98
# 2       87 Sylvia (A866 KA)  0.0939  3.151  10.88   73.01  264.40  3.80
# 3     107 Camilla (A868 WA)  0.0653  3.258  10.00  172.59  305.22  3.71
# 4      108 Hecuba (A869 GB)  0.0625  3.031   4.21  349.76  212.59  3.44
#
#          tp_cal  per_y class  data_arc  condition_code  n_obs_used      a  \
# 0  2021-02-01.8   6.34   OMB   59325.0             0.0        4605  3.426
# 1  2020-08-23.2   6.30   OMB   58203.0             0.0        5856  3.412
# 2  2024-02-25.6   6.48   OMB   50497.0             0.0        5573  3.477
# ...

# %%
#need to fix na values
